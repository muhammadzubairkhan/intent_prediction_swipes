# %%
# %matplotlib inline

# %% [markdown]
# # Intent Prediction Via Swipes
#
# This notebook is for the members of our projects. Please comment with your name while you add something new and useful in the code.
# I will keep the original file as backup.

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.utils.validation import check_random_state

from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

data = pd.read_csv("../emonxcsv.csv", index_col = 0)
data.plot()

print("INITIAL 10 RECORDS")
print(data.head(n = 10))

print("LAST 10 RECORDS")
print(data.tail(n = 10))

print("INDEX")
print(data.index)

print("COLUMNS")
print(data.columns)

print("INFORMATION/DESCRIPTION OF DATA")
print(data.describe)

print("SPECIFIC COLUMN HEAD")
print(data.ObjectID.head())

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# INITIAL 10 RECORDS
#                    ObjectID StartTime           Label ActivityName    Gesture  \
# 0  5c0a8c7418ded300018d299d       NaN  Product Viewed  Smartphones     onDown
# 1  5c0a8c7418ded300018d299d       NaN             NaN  Smartphones  onScroll1
# 2  5c0a8c7418ded300018d299d       NaN             NaN  Smartphones  onScroll2
# 3  5c0a8c7418ded300018d299d       NaN             NaN  Smartphones  onScroll1
# 4  5c0a8c7418ded300018d299d       NaN             NaN  Smartphones  onScroll2
# 5  5c0a8c7418ded300018d299d       NaN             NaN  Smartphones  onScroll1
# 6  5c0a8c7418ded300018d299d       NaN             NaN  Smartphones  onScroll2
# 7  5c0a8c7418ded300018d299d       NaN             NaN  Smartphones  onScroll1
# 8  5c0a8c7418ded300018d299d       NaN             NaN  Smartphones  onScroll2
# 9  5c0a8c7418ded300018d299d       NaN             NaN  Smartphones  onScroll1
#
# ...
